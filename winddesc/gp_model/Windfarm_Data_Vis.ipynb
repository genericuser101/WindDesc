# %% [markdown]
# ### Data Visualisation Notebook

# %% [markdown]
# This jupyter notebook is responsible for visualising the data already present in the *all_datasetV2.csv* file, this is done to aid the active learning processes.

# %%
#Used to interact with plots
# %matplotlib notebook

#This is done until WDPackage is a standalone download.
import sys
sys.path.append("../WDPackage")
import CSV_utility

#Sets up vision tool which take in the parameter of a CSV file name. 
Vis_Tool = CSV_utility.CSV_Data_Vis("../../data/all_Dataset_V2.csv")

# %%
Tool = CSV_utility.CSV_Helper()

thisthing = Tool.get_last_sim("../../data/all_Dataset_V2.csv", 3)
print(thisthing)
# Out:
# 360.0

# %% [markdown]
# **2 Turbine Data:** Here we are visualing the spread of data for a 2 turbine model, you will be able to see clear spread stemming from the first turbine which is sat at (0,0).

# %%
Vis_Tool.display_2T_data()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **3 Turbine Data:** Here we are visualing the spread of data for a 3 turbine model, you will be able to see clear spread stemming from the first turbine which is sat at (0,0).

# %%
Vis_Tool.display_3T_data()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **3 Turbine Windpath Flow:** Now we will be introducing the lined approach to observe the line paths throughout the three turbines, instead of seeing an uncorrelated set of data we can visualise the "closest wake path".

# %%
Vis_Tool.display_3T_windpath()
# Out:
# <img src="data:image/png;base64,..." width="4000">

# %% [markdown]
# **3 Turbine Discriptor Data:** Here we will proceed with doing data visualisation on the 3 Hyperparemters/Descirptors for 3T, becuase I dont think there is any use in further throwing effort at the 2T as we are now moving onto 4T setups. \
# \
# This is done to further help witht understanding where the biggest gaps in the data are.

# %%
Vis_Tool.display_3T_predictors()
# Out:
# <img src="data:image/png;base64,..." width="640">
